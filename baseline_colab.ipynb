# %%
# !python --version
# Out:
# Python 3.14.5

# %%
import time
import statistics
import networkx as nx

N_WARMUP = 2
N_RUNS = 7

GRAPH_NODES = 3000

def workload():
    G = nx.barabasi_albert_graph(GRAPH_NODES, 5)
    return nx.betweenness_centrality(G)

times = []

for _ in range(N_WARMUP):
    workload()

for i in range(N_RUNS):
    start = time.perf_counter()

    workload()

    end = time.perf_counter()

    elapsed = end - start
    times.append(elapsed)

    print(f"Run {i+1}: {elapsed:.2f}")

median = statistics.median(times)

quartiles = statistics.quantiles(times, n=4)
iqr = quartiles[2] - quartiles[0]

print("Median:", median)
print("IQR:", iqr)
# Out:
# Run 1: 28.44
# Run 2: 27.06
# Run 3: 27.48
# Run 4: 27.52
# Run 5: 29.70
# Run 6: 27.40
# Run 7: 27.07
# Median: 27.47821230000045
# IQR: 1.374536000000262
