# %%
# !python --version
# Out:
# Python 3.14.5

# %%
import networkx as nx

G = nx.barabasi_albert_graph(1000, 5)

result = nx.betweenness_centrality(G)

print("Validation successful")
print("Computed nodes:", len(result))
# Out:
# Validation successful
# Computed nodes: 1000

# %%
# !python -m pytest networkx/algorithms/tests/
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.14.5, pytest-9.0.3, pluggy-1.6.0
# rootdir: C:\Users\fatema\perf_takehome\networkx
# configfile: pyproject.toml
# plugins: anyio-4.13.0, locust-2.44.0
# collected 1799 items / 5 skipped
#
# networkx\algorithms\tests\test_asteroidal.py .                           [  0%]
# networkx\algorithms\tests\test_boundary.py .............                 [  0%]
# networkx\algorithms\tests\test_bridges.py ..........                     [  1%]
# networkx\algorithms\tests\test_broadcasting.py ......................... [  2%]
# ............                                                             [  3%]
# networkx\algorithms\tests\test_chains.py .....                           [  3%]
# networkx\algorithms\tests\test_chordal.py .................              [  4%]
# networkx\algorithms\tests\test_clique.py .............                   [  5%]
# networkx\algorithms\tests\test_cluster.py .............................. [  7%]
# ..........................                                               [  8%]
# networkx\algorithms\tests\test_core.py .........................         [  9%]
# networkx\algorithms\tests\test_covering.py ...........                   [ 10%]
# networkx\algorithms\tests\test_cuts.py .................                 [ 11%]
# networkx\algorithms\tests\test_cycles.py ............................... [ 13%]
# .................ss.ss..........                                         [ 14%]
# networkx\algorithms\tests\test_d_separation.py .................         [ 15%]
# networkx\algorithms\tests\test_dag.py .................................. [ 17%]
# ........................................                                 [ 19%]
# networkx\algorithms\tests\test_distance_measures.py .................... [ 21%]
# ........................................................................ [ 25%]
# ........................................................................ [ 29%]
# ........................................................................ [ 33%]
# ........................................................................ [ 37%]
# ........................................................................ [ 41%]
# ........................................................................ [ 45%]
# ........................................................................ [ 49%]
# .........................................ssssssssssssssssssssssssss..... [ 53%]
# sssssssssss                                                              [ 53%]
# networkx\algorithms\tests\test_distance_regular.py ...............       [ 54%]
# networkx\algorithms\tests\test_dominance.py ............................ [ 56%]
# ......                                                                   [ 56%]
# networkx\algorithms\tests\test_dominating.py ....................        [ 57%]
# networkx\algorithms\tests\test_efficiency.py .......                     [ 57%]
# networkx\algorithms\tests\test_euler.py ................................ [ 59%]
# ..                                                                       [ 59%]
# networkx\algorithms\tests\test_graph_hashing.py ........................ [ 61%]
# ......                                                                   [ 61%]
# networkx\algorithms\tests\test_graphical.py .............                [ 62%]
# networkx\algorithms\tests\test_hierarchy.py ........                     [ 62%]
# networkx\algorithms\tests\test_hybrid.py ..                              [ 62%]
# networkx\algorithms\tests\test_isolate.py ...                            [ 62%]
# networkx\algorithms\tests\test_link_prediction.py ...................... [ 64%]
# ........................................................................ [ 68%]
# ...                                                                      [ 68%]
# networkx\algorithms\tests\test_lowest_common_ancestors.py .............. [ 69%]
# .............................................                            [ 71%]
# networkx\algorithms\tests\test_matching.py ............................. [ 73%]
# ..........................................                               [ 75%]
# networkx\algorithms\tests\test_max_weight_clique.py .....                [ 75%]
# networkx\algorithms\tests\test_mis.py .......                            [ 76%]
# networkx\algorithms\tests\test_moral.py .                                [ 76%]
# networkx\algorithms\tests\test_non_randomness.py ..............          [ 77%]
# networkx\algorithms\tests\test_perfect_graph.py .....                    [ 77%]
# networkx\algorithms\tests\test_planar_drawing.py ............            [ 77%]
# networkx\algorithms\tests\test_planarity.py ............................ [ 79%]
# ................                                                         [ 80%]
# networkx\algorithms\tests\test_reciprocity.py .....                      [ 80%]
# networkx\algorithms\tests\test_regular.py .............................. [ 82%]
#                                                                          [ 82%]
# networkx\algorithms\tests\test_richclub.py ...........                   [ 82%]
# networkx\algorithms\tests\test_similarity.py ...ssssssssssssssssssssssss [ 84%]
# ssssssssssssssssssssssssssssssssssssssssssssss                           [ 87%]
# networkx\algorithms\tests\test_simple_paths.py ......................... [ 88%]
# ......................................................                   [ 91%]
# networkx\algorithms\tests\test_smallworld.py ......                      [ 91%]
# networkx\algorithms\tests\test_smetric.py .                              [ 91%]
# networkx\algorithms\tests\test_sparsifiers.py .......                    [ 92%]
# networkx\algorithms\tests\test_summarization.py .................        [ 93%]
# networkx\algorithms\tests\test_swap.py ...........................       [ 94%]
# networkx\algorithms\tests\test_threshold.py .................s.          [ 95%]
# networkx\algorithms\tests\test_time_dependent.py ............            [ 96%]
# networkx\algorithms\tests\test_tournament.py ...............s.....       [ 97%]
# networkx\algorithms\tests\test_triads.py ..............                  [ 98%]
# networkx\algorithms\tests\test_vitality.py ......                        [ 98%]
# networkx\algorithms\tests\test_voronoi.py ..........                     [ 99%]
# networkx\algorithms\tests\test_wiener.py ..............                  [100%]
#
# ===================== 1686 passed, 118 skipped in 28.02s ======================
